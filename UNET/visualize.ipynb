# %%
cd logscale
# Out:
# /work/data/sony/1105/model/logscale

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from scaler import LogScaler
import UNET
from sklearn.metrics import r2_score
from classUnet import Unet
from visualize import visualize, last_visualize, horizontal_plot, vertical_plot
# Out:
# /work/data/sony/1105/model/logscale
# (1000, 3, 21, 41)
# (1000, 2)
# (1000, 1, 21, 41)

# %%
#保存モデル読み込み
model = Unet()
model.load_state_dict(torch.load("UNET_0.983(mape)_log.pth"))

test_pred = UNET.scaler_out.inverse(model(UNET.twoD_x_test_tensor_scaled, UNET.oneD_x_test_tensor_scaled))

# %% [markdown]
# ### 0個目のデータ

# %%
n = 0

# %%
#一回目のskip connectionの画像
visualize(data=model.skip1, n=n)

# %%
#umsample2回目
visualize(data=model.encode2, n=n)

# %%
#upsample+skip connectionを1回たたみ込んだ画像 [16, 20, 40]
visualize(model.encode2_1, n=n)

# %%
#upsample+skip connectionを2回たたみ込んだ画像 [16, 20, 40]
visualize(model.encode2_2, n=n)

# %%
last_visualize(n, sim=UNET.y_test, pred=test_pred)
# Out:
# tensor([700.,  84.])

# %%
#縦切りプロット
vertical_plot(n=n, x=0, sim=UNET.y_test, pred=test_pred)

# %%
#縦切りプロット
vertical_plot(n=n, x=20, sim=UNET.y_test, pred=test_pred)

# %%
#縦切りプロット
vertical_plot(n=n, x=40, sim=UNET.y_test, pred=test_pred)

# %%
#横切りプロット
horizontal_plot(n=n, y=0, sim=UNET.y_test, pred=test_pred)

# %%
#横切りプロット
horizontal_plot(n=n, y=10, sim=UNET.y_test, pred=test_pred)

# %%
#横切りプロット
horizontal_plot(n=n, y=20, sim=UNET.y_test, pred=test_pred)

# %% [markdown]
# ### 11個目のデータ

# %%
n=11

# %%
visualize(model.skip1, n)

# %% [markdown]
# ### deconv2回目

# %%
visualize(model.encode2, n)

# %% [markdown]
# ### deconv+skipのconv1回目

# %%
visualize(model.encode2_1, n)

# %% [markdown]
# ### deconv+skipのconv2回目

# %%
visualize(model.encode2_2, n)

# %% [markdown]
# ### 最終出力

# %%
last_visualize(n, sim=UNET.y_test, pred=test_pred)
# Out:
# tensor([ 819., 3670.])

# %%
#縦切りプロット
vertical_plot(n=n, x=0, sim=UNET.y_test, pred=test_pred, low=10, up=18)

# %%
vertical_plot(n=n, x=20, sim=UNET.y_test, pred=test_pred, low=15, up=18)

# %%
vertical_plot(n=n, x=40, sim=UNET.y_test, pred=test_pred, low=10, up=18)

# %%
#横切りプロット
horizontal_plot(n=n, y=0, sim=UNET.y_test, pred=test_pred, low=10, up=18)

# %%
horizontal_plot(n=n, y=10, sim=UNET.y_test, pred=test_pred, low=10, up=18)

# %%
horizontal_plot(n=n, y=20, sim=UNET.y_test, pred=test_pred, low=10, up=18)
